# %%
#Import the necessary libraries
import core.coreapi as coreapi
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook
import plotly.graph_objs as go
from matplotlib import colormaps
import datetime

# %%
#Instatiate the API class

qmapi = coreapi.QuantmatixAPI()
# Out:
# Working in environment: PROD

# %% [markdown]
# <h1> INSIDER EMPLOYEE TRADES <h1>

# %%
#First need to define the SQL string

#this specifically takes the trading done by employees of a company
sql_query = """
SELECT [TickerId]
      ,[FilingDate]
      ,[TransactionDate]
      ,[ReportingCik]
      ,[CompanyCik]
      ,[TransactionType]
      ,[SecuritiesOwned]
      ,[SecuritiesTransacted]
      ,[ReportingName]
      ,[TypeOfOwner]
      ,[Link]
      ,[SecurityName]
      ,[Price]
      ,[FormType]
      ,[AcquisitionOrDisposition]
  FROM [dbo].[TickerInsiderTradingFMP]
"""
sql_db_name = "STUDY_DATABASE_NAME"

# %%
#Read in the data
insider_data = qmapi.get_data_sql(sql_string=sql_query,
                                  db_name=sql_db_name)
insider_data.head()
# Out:
#    TickerId          FilingDate TransactionDate ReportingCik  CompanyCik  \
# 0     12265 2003-05-05 10:58:35      2003-05-01   0001183377  0001144215
# 1     12265 2003-05-05 11:12:49      2003-05-01   0001183380  0001144215
# 2      4641 2003-05-05 15:44:13      2003-05-02   0001199338  0000034088
# 3     13262 2003-05-05 16:39:32      2003-05-02   0001182403  0000833640
# 4      4641 2003-05-05 16:45:07      2003-05-02   0001198809  0000034088
#
#   TransactionType  SecuritiesOwned  SecuritiesTransacted  \
# 0         A-Award           3814.0                  39.0
# 1         A-Award           3814.0                  39.0
# 2        M-Exempt          20000.0               16824.0
# 3        M-Exempt         270097.0               15000.0
# 4        M-Exempt         700000.0              100000.0
#
#              ReportingName                                TypeOfOwner  \
# 0  DEAVENPORT EARNEST W JR                                   director
# 1            NORTH JULIA B                                   director
# 2          CRAMER HAROLD R                    officer: Vice President
# 3           EARHART HOWARD                                   director
# 4            RAYMOND LEE R  director, officer: Chairman and President
#
#                                                 Link  \
# 0  https://www.sec.gov/Archives/edgar/data/118337...
# 1  https://www.sec.gov/Archives/edgar/data/118338...
# 2  https://www.sec.gov/Archives/edgar/data/34088/...
# 3  https://www.sec.gov/Archives/edgar/data/118240...
# 4  https://www.sec.gov/Archives/edgar/data/34088/...
#
#                                SecurityName   Price FormType  \
# 0                               Stock Units   0.000        4
# 1                               Stock Units   0.000        4
# 2      Employee Stock Option (Right to Buy)  15.280        4
# 3  Non-Qualified Stock Option(right to buy)  12.100        4
# 4      Employee Stock Option (Right to Buy)  15.125        4
#
#   AcquisitionOrDisposition
# 0                        A
# 1                        A
# 2                        D
# 3                        D
# 4                        D

# %%
#first find the types of transactions in the dataset
trans_type = insider_data['TransactionType'].unique()
print(trans_type)

#we have many different types of transactions...
# Out:
# ['A-Award' 'M-Exempt' 'P-Purchase' 'C-Conversion' 'X-InTheMoney' 'S-Sale'
#  'J-Other' 'G-Gift' 'E-ExpireShort' 'I-Discretionary' 'D-Return'
#  'H-ExpireLong' 'W-Will' 'F-InKind' 'Z-Trust' 'L-Small' 'U-Tender'
#  'O-OutOfTheMoney']

# %%
#this returns the stocks with the most insider trades
insider_data['TickerId'].value_counts().head(20)

#lets look into the most inside traded stock, which today is 1910 = Salesforce (CRM)
# Out:
# TickerId
# 4545     7533
# 12780    6452
# 4195     6205
# 2687     5271
# 1333     5181
# 12618    5170
# 1434     5149
# 1268     5050
# 1940     5004
# 2737     4814
# 4678     4762
# 1692     4761
# 2862     4725
# 12465    4598
# 13229    4503
# 3407     4429
# 2542     4406
# 12528    4375
# 3589     4336
# 3630     4120
# Name: count, dtype: int64

# %%
ticker_of_choice = 1414

####################################################################################################

#change dataset to have only the ticker of choice trades
ticker_df = insider_data[(insider_data['TickerId'] == ticker_of_choice)] #get all the trades associated with our stock of choice

#get data of ticker from API
ticker_of_choice_data = qmapi.get_tickers_data(tickers_list=[ticker_of_choice])

#read in stock ticker data from yahoo finance

#our start date is the first recorded trade for reading in Yahoo data
start_date=ticker_df['TransactionDate'].min()

#our end date is today
end_date=datetime.date.today()

#ticker short name got from API data
ticker = ticker_of_choice_data['shortName'].str.split(':').str[0]

#read in historical price data
ticker_data = yf.download(ticker[0], start=start_date, end=end_date, interval='1d')

########################################################################################################


#CREATE THE PLOT

highlight_dates  = ticker_df['TransactionDate'] #take dates of transactions
highlight_dates = pd.to_datetime(highlight_dates) #convert to datetime
transaction_type = ticker_df['TransactionType'] #take all transaction types associated with the dates

highlight_df = pd.DataFrame({'Date':highlight_dates, 'Type':transaction_type}) #make a new dataframe containing dates and types

#find the number of unique transaction types
unique_types = highlight_df['Type'].unique()
num_types = len(unique_types)

# Use a colormap to assign colors (using matplotlib for color generation)
colors = colormaps['Set1'](np.linspace(0, 1, num_types))  
color_map = {typ: f'rgb({int(c[0] * 255)}, {int(c[1] * 255)}, {int(c[2] * 255)})'
              for typ, c in zip(unique_types, colors)}  # Map each type to a color

def get_next_available_date(date, ticker_index):
    max_date = ticker_index.max()
    while date not in ticker_index and date <= max_date:
        date += pd.Timedelta(days=1)
    return date if date in ticker_index else None

#plot ticker and transaction dates
fig = go.Figure()

#plot ticker data
fig.add_trace(go.Scatter(x=ticker_data.index, 
                         y=ticker_data['Close'],
                         mode='lines',
                         name=f'{ticker[0]} Daily Close Price'))

#plot transaction dates and types
legend_added = set()

for _, row in highlight_df.iterrows():
    date = row['Date']
    type = row['Type']
    adjusted_date = date if date in ticker_data.index else get_next_available_date(date, ticker_data.index)
    if adjusted_date in ticker_data.index:
        fig.add_trace(go.Scatter(x = [date],
                                y = [ticker_data.loc[adjusted_date, 'Close']],
                                mode='markers',
                                name=type,
                                marker=dict(color=color_map[type], size=8),
                                showlegend=type not in legend_added,
                                legendgroup=type,
                                visible='legendonly'
                                ))
        legend_added.add(type)
    else:
        print(f"Date {date} not found in ticker_data index.") #sometimes the date is not in the ticker data, so this avoids an error
    

fig.update_layout(
    title = f'{ticker_of_choice_data['instrumentName'].iloc[0]} Historical Price & Insider Dealings',
    xaxis_title = 'Date',
    yaxis_title = 'Price',
    showlegend = True,
    legend = dict(groupclick="togglegroup")
)

fig.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ticker_df[ticker_df['TransactionType'] == 'S-Sale']
# Out:
#          TickerId ReportingCik  CompanyCik TransactionType  SecuritiesOwned  \
# 446663       3630   0001198053  0000713676          S-Sale         253615.0
# 447160       3630   0001198053  0000713676          S-Sale         490847.0
# 447598       3630   0001198053  0000713676          S-Sale         221615.0
# 447617       3630   0001198053  0000713676          S-Sale         248251.0
# 448010       3630   0001198053  0000713676          S-Sale         189951.0
# 448144       3630   0001198053  0000713676          S-Sale         190953.0
# 448187       3630   0001198053  0000713676          S-Sale         191023.0
# 448478       3630   0001198053  0000713676          S-Sale         225951.0
# 448603       3630   0001198053  0000713676          S-Sale         258762.0
# 448988       3630   0001198053  0000713676          S-Sale         256207.0
# 449352       3630   0001198053  0000713676          S-Sale         462445.0
# 449396       3630   0001198053  0000713676          S-Sale         393755.0
# 449707       3630   0001198053  0000713676          S-Sale         582179.0
# 449984       3630   0001198053  0000713676          S-Sale         568964.0
# 450047       3630   0001198053  0000713676          S-Sale         281839.0
# 450074       3630   0001198053  0000713676          S-Sale         358551.0
# 450284       3630   0001198053  0000713676          S-Sale         501732.0
# 450405       3630   0001198053  0000713676          S-Sale         370790.0
# 1493536      3630   0001198053  0000713676          S-Sale         568323.0
# 1540021      3630   0001198053  0000713676          S-Sale         567682.0
# 1648879      3630   0001198053  0000713676          S-Sale         567041.0
# 1659041      3630   0001198053  0000713676          S-Sale         564637.0
# 1660176      3630   0001198053  0000713676          S-Sale         563395.0
# 1699177      3630   0001198053  0000713676          S-Sale         562153.0
# 1726673      3630   0001198053  0000713676          S-Sale         560911.0
# 1769510      3630   0001198053  0000713676          S-Sale         559669.0
# 1795119      3630   0001198053  0000713676          S-Sale         558427.0
# 1805176      3630   0001198053  0000713676          S-Sale         557185.0
# 1864757      3630   0001198053  0000713676          S-Sale         555943.0
# 1866444      3630   0001198053  0000713676          S-Sale         554701.0
# 1868156      3630   0001198053  0000713676          S-Sale         553459.0
# 1869412      3630   0001198053  0000713676          S-Sale         552217.0
# 1871099      3630   0001198053  0000713676          S-Sale         550975.0
# 1873840      3630   0001198053  0000713676          S-Sale         549733.0
# 1877105      3630   0001198053  0000713676          S-Sale         548491.0
# 1878348      3630   0001198053  0000713676          S-Sale         547249.0
# 1879549      3630   0001198053  0000713676          S-Sale         546007.0
# 1882478      3630   0001198053  0000713676          S-Sale         544765.0
#
#          SecuritiesTransacted      ReportingName  \
# 446663                  100.0  DEMCHAK WILLIAM S
# 447160               165442.0  DEMCHAK WILLIAM S
# 447598                  800.0  DEMCHAK WILLIAM S
# 447617                  700.0  DEMCHAK WILLIAM S
# 448010                 8600.0  DEMCHAK WILLIAM S
# 448144                63094.0  DEMCHAK WILLIAM S
# 448187                63024.0  DEMCHAK WILLIAM S
# 448478                  600.0  DEMCHAK WILLIAM S
# 448603                34900.0  DEMCHAK WILLIAM S
# 448988                56584.0  DEMCHAK WILLIAM S
# 449352               162810.0  DEMCHAK WILLIAM S
# 449396                82500.0  DEMCHAK WILLIAM S
# 449707                75000.0  DEMCHAK WILLIAM S
# 449984                  641.0  DEMCHAK WILLIAM S
# 450047               110000.0  DEMCHAK WILLIAM S
# 450074                68000.0  DEMCHAK WILLIAM S
# 450284                 6247.0  DEMCHAK WILLIAM S
# 450405               120057.0  DEMCHAK WILLIAM S
# 1493536                 641.0  DEMCHAK WILLIAM S
# 1540021                 641.0  DEMCHAK WILLIAM S
# 1648879                 641.0  DEMCHAK WILLIAM S
# 1659041                2404.0  DEMCHAK WILLIAM S
# 1660176                1242.0  DEMCHAK WILLIAM S
# 1699177                1242.0  DEMCHAK WILLIAM S
# 1726673                1242.0  DEMCHAK WILLIAM S
# 1769510                1242.0  DEMCHAK WILLIAM S
# 1795119                1242.0  DEMCHAK WILLIAM S
# 1805176                1242.0  DEMCHAK WILLIAM S
# 1864757                1242.0  DEMCHAK WILLIAM S
# 1866444                1242.0  DEMCHAK WILLIAM S
# 1868156                1242.0  DEMCHAK WILLIAM S
# 1869412                1242.0  DEMCHAK WILLIAM S
# 1871099                1242.0  DEMCHAK WILLIAM S
# 1873840                1242.0  DEMCHAK WILLIAM S
# 1877105                1242.0  DEMCHAK WILLIAM S
# 1878348                1242.0  DEMCHAK WILLIAM S
# 1879549                1242.0  DEMCHAK WILLIAM S
# 1882478                1242.0  DEMCHAK WILLIAM S
#
#                            TypeOfOwner         SecurityName     Price  \
# 446663          officer: Vice Chairman  $5 Par Common Stock   70.2900
# 447160          officer: President/CEO  $5 Par Common Stock  127.1028
# 447598          officer: Vice Chairman  $5 Par Common Stock   70.6600
# 447617          officer: Vice Chairman  $5 Par Common Stock   75.5300
# 448010          officer: Vice Chairman  $5 Par Common Stock   75.6100
# 448144          officer: Vice Chairman  $5 Par Common Stock   71.9374
# 448187          officer: Vice Chairman  $5 Par Common Stock   71.9374
# 448478          officer: Vice Chairman  $5 Par Common Stock   75.9000
# 448603   officer: Senior Vice Chairman  $5 Par Common Stock   55.5200
# 448988          officer: President/CEO  $5 Par Common Stock   75.4357
# 449352          officer: President/CEO  $5 Par Common Stock  107.5546
# 449396          officer: President/CEO  $5 Par Common Stock   95.3146
# 449707          officer: President/CEO  $5 Par Common Stock  140.6330
# 449984          director, officer: CEO  $5 Par Common Stock  150.0700
# 450047          officer: President/CEO  $5 Par Common Stock   87.9469
# 450074          officer: President/CEO  $5 Par Common Stock   91.5240
# 450284          officer: President/CEO  $5 Par Common Stock  134.7970
# 450405          officer: President/CEO  $5 Par Common Stock  152.0500
# 1493536         director, officer: CEO  $5 Par Common Stock  153.1900
# 1540021         director, officer: CEO  $5 Par Common Stock  153.0800
# 1648879         director, officer: CEO  $5 Par Common Stock  158.1000
# 1659041         director, officer: CEO  $5 Par Common Stock  160.0000
# 1660176         director, officer: CEO  $5 Par Common Stock  167.5000
# 1699177         director, officer: CEO  $5 Par Common Stock  176.6700
# 1726673         director, officer: CEO  $5 Par Common Stock  180.4800
# 1769510         director, officer: CEO  $5 Par Common Stock  173.8200
# 1795119         director, officer: CEO  $5 Par Common Stock  170.1100
# 1805176         director, officer: CEO  $5 Par Common Stock  171.8000
# 1864757         director, officer: CEO  $5 Par Common Stock  176.1500
# 1866444         director, officer: CEO  $5 Par Common Stock  183.1700
# 1868156         director, officer: CEO  $5 Par Common Stock  180.7100
# 1869412         director, officer: CEO  $5 Par Common Stock  178.1000
# 1871099         director, officer: CEO  $5 Par Common Stock  186.4500
# 1873840         director, officer: CEO  $5 Par Common Stock  183.7400
# 1877105         director, officer: CEO  $5 Par Common Stock  181.3500
# 1878348         director, officer: CEO  $5 Par Common Stock  185.0000
# 1879549         director, officer: CEO  $5 Par Common Stock  190.5700
# 1882478         director, officer: CEO  $5 Par Common Stock  190.2700
#
#         FormType AcquisitionOrDisposition TransactionDate          FilingDate
# 446663         4                        D      2006-11-29 2006-12-01 16:07:17
# 447160         4                        D      2017-02-28 2017-03-02 13:58:09
# 447598         4                        D      2006-11-29 2006-12-01 16:09:00
# 447617         4                        D      2007-02-20 2007-02-22 16:12:04
# 448010         4                        D      2007-02-15 2007-02-16 16:25:25
# 448144       4/A                        D      2008-07-31 2008-08-04 16:18:51
# 448187         4                        D      2008-07-31 2008-08-01 16:17:57
# 448478         4                        D      2007-02-20 2007-02-22 16:17:54
# 448603         4                        D      2011-12-05 2011-12-07 17:34:54
# 448988         4                        D      2013-10-23 2013-10-25 16:27:13
# 449352         4                        D      2016-11-14 2016-11-16 16:10:31
# 449396         4                        D      2016-10-27 2016-10-31 14:34:55
# 449707         4                        D      2019-07-23 2019-07-24 15:25:58
# 449984         4                        D      2024-06-14 2024-06-18 16:37:10
# 450047         4                        D      2014-11-24 2014-11-25 13:39:59
# 450074         4                        D      2015-04-20 2015-04-22 14:31:39
# 450284         4                        D      2019-09-12 2019-09-13 12:10:49
# 450405         4                        D      2019-11-08 2019-11-13 16:19:35
# 1493536        4                        D      2024-06-21 2024-06-25 10:59:51
# 1540021        4                        D      2024-06-28 2024-07-01 15:15:56
# 1648879        4                        D      2024-07-05 2024-07-08 13:19:17
# 1659041        4                        D      2024-07-09 2024-07-11 14:40:38
# 1660176        4                        D      2024-07-12 2024-07-15 16:36:24
# 1699177        4                        D      2024-07-19 2024-07-22 16:19:14
# 1726673        4                        D      2024-07-26 2024-07-29 14:17:23
# 1769510        4                        D      2024-08-02 2024-08-06 11:05:27
# 1795119        4                        D      2024-08-09 2024-08-13 10:32:22
# 1805176        4                        D      2024-08-16 2024-08-20 12:15:12
# 1864757        4                        D      2024-08-23 2024-08-27 15:01:21
# 1866444        4                        D      2024-08-30 2024-09-04 11:13:48
# 1868156        4                        D      2024-09-06 2024-09-10 16:03:40
# 1869412        4                        D      2024-09-13 2024-09-16 15:35:21
# 1871099        4                        D      2024-09-20 2024-09-23 16:23:55
# 1873840        4                        D      2024-09-27 2024-09-30 17:00:30
# 1877105        4                        D      2024-10-04 2024-10-07 14:50:30
# 1878348        4                        D      2024-10-11 2024-10-15 14:25:52
# 1879549        4                        D      2024-10-18 2024-10-21 13:45:44
# 1882478        4                        D      2024-10-25 2024-10-28 15:15:14

# %%
ticker_df
# Out:
#          TickerId ReportingCik  CompanyCik TransactionType  SecuritiesOwned  \
# 446556       3630   0001198053  0000713676         J-Other          40889.0
# 446565       3630   0001198053  0000713676      P-Purchase         110110.0
# 446586       3630   0001198053  0000713676         J-Other          42212.0
# 446599       3630   0001198053  0000713676         J-Other           1581.0
# 446609       3630   0001198053  0000713676         J-Other           1764.0
# ...           ...          ...         ...             ...              ...
# 1873840      3630   0001198053  0000713676          S-Sale         549733.0
# 1877105      3630   0001198053  0000713676          S-Sale         548491.0
# 1878348      3630   0001198053  0000713676          S-Sale         547249.0
# 1879549      3630   0001198053  0000713676          S-Sale         546007.0
# 1882478      3630   0001198053  0000713676          S-Sale         544765.0
#
#          SecuritiesTransacted      ReportingName  \
# 446556                28171.0  DEMCHAK WILLIAM S
# 446565                 4600.0  DEMCHAK WILLIAM S
# 446586                  389.0  DEMCHAK WILLIAM S
# 446599                   23.0  DEMCHAK WILLIAM S
# 446609                   24.0  DEMCHAK WILLIAM S
# ...                       ...                ...
# 1873840                1242.0  DEMCHAK WILLIAM S
# 1877105                1242.0  DEMCHAK WILLIAM S
# 1878348                1242.0  DEMCHAK WILLIAM S
# 1879549                1242.0  DEMCHAK WILLIAM S
# 1882478                1242.0  DEMCHAK WILLIAM S
#
#                             TypeOfOwner         SecurityName   Price FormType  \
# 446556   officer: Vice Chairman and CFO   Phantom Stock Unit    0.00        4
# 446565   officer: Vice Chairman and CFO  $5 Par Common Stock   46.69        4
# 446586   officer: Vice Chairman and CFO   Phantom Stock Unit    0.00        4
# 446599   officer: Vice Chairman and CFO   Phantom Stock Unit    0.00        4
# 446609           officer: Vice Chairman   Phantom Stock Unit    0.00        4
# ...                                 ...                  ...     ...      ...
# 1873840          director, officer: CEO  $5 Par Common Stock  183.74        4
# 1877105          director, officer: CEO  $5 Par Common Stock  181.35        4
# 1878348          director, officer: CEO  $5 Par Common Stock  185.00        4
# 1879549          director, officer: CEO  $5 Par Common Stock  190.57        4
# 1882478          director, officer: CEO  $5 Par Common Stock  190.27        4
#
#         AcquisitionOrDisposition TransactionDate          FilingDate
# 446556                         A      2004-04-26 2004-04-28 16:08:45
# 446565                         A      2004-07-23 2004-07-26 13:15:15
# 446586                         A      2005-01-24 2005-02-18 15:32:29
# 446599                         A      2005-06-30 2005-07-05 11:08:00
# 446609                         A      2005-10-06 2005-10-07 14:54:17
# ...                          ...             ...                 ...
# 1873840                        D      2024-09-27 2024-09-30 17:00:30
# 1877105                        D      2024-10-04 2024-10-07 14:50:30
# 1878348                        D      2024-10-11 2024-10-15 14:25:52
# 1879549                        D      2024-10-18 2024-10-21 13:45:44
# 1882478                        D      2024-10-25 2024-10-28 15:15:14
#
# [253 rows x 14 columns]
