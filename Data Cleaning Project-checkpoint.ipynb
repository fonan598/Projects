# %% [markdown]
# # Data Cleaning Project

# %% [markdown]
# - we'll work with exit surveys from employees of the Department of Education, Training and Employment (DETE) and the Technical and Further Education (TAFE) institute in Queensland, Australia.
# - In this project, we'll play the role of data analyst and pretend our stakeholders want to know the following:
#
#     - Are employees who only worked for the institutes for a short period of time resigning due to some kind of dissatisfaction? What about employees who have been there longer?
#     - Are younger employees resigning due to some kind of dissatisfaction? What about older employees?
#
# - They want us to combine the results for both surveys to answer these questions. However, although both used the same survey template, one of them customized some of the answers.

# %% [markdown]
# - Below is a preview of a couple columns we'll work with from the dete_survey.csv:
#     - ID: An id used to identify the participant of the survey
#     - SeparationType: The reason why the person's employment ended
#     - Cease Date: The year or month the person's employment ended
#     - DETE Start Date: The year the person began employment with the DETE

# %% [markdown]
# - Below is a preview of a couple columns we'll work with from the tafe_survey.csv:
#
#     - Record ID: An id used to identify the participant of the survey
#     - Reason for ceasing employment: The reason why the person's employment ended
#     - LengthofServiceOverall. Overall Length of Service at Institute (in years): The length of the person's employment (in years)

# %%
import pandas as pd
import numpy as np

# %%
#read in our data

dete_survey = pd.read_csv('dete_survey.csv', na_values='Not Stated')
tafe_survey = pd.read_csv('tafe_survey.csv', na_values='-')

# %%
#do a little exploratory analysis on our two datasets

dete_survey.info()
# we have 55 cols to our dataset
# and 822 observations 
# 18 of which are bools, 1 int and 37 objects

dete_survey.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 56 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ID                                   822 non-null    int64
#  1   SeparationType                       822 non-null    object
#  2   Cease Date                           788 non-null    object
#  3   DETE Start Date                      749 non-null    float64
#  4   Role Start Date                      724 non-null    float64
#  5   Position                             817 non-null    object
#  6   Classification                       455 non-null    object
#  7   Region                               717 non-null    object
#  8   Business Unit                        126 non-null    object
#  9   Employment Status                    817 non-null    object
#  10  Career move to public sector         822 non-null    bool
# ...

# %%
tafe_survey.info()
tafe_survey.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702 entries, 0 to 701
# Data columns (total 72 columns):
#  #   Column                                                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                                                         --------------  -----
#  0   Record ID                                                                                                                                                      702 non-null    float64
#  1   Institute                                                                                                                                                      702 non-null    object
# ...

# %%
dete_survey_updated = dete_survey.drop(dete_survey.columns[28:49], axis=1)

# %%
tafe_survey_updated = tafe_survey.drop(tafe_survey.columns[17:66], axis=1)

# %% [markdown]
# - We removed the columns 28-49 from the DETE survey and 17-66 from the TAFE survey, as they aren't important to the questions we are trying to answer

# %%
dete_survey_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ID                                   822 non-null    int64
#  1   SeparationType                       822 non-null    object
#  2   Cease Date                           788 non-null    object
#  3   DETE Start Date                      749 non-null    float64
#  4   Role Start Date                      724 non-null    float64
#  5   Position                             817 non-null    object
#  6   Classification                       455 non-null    object
#  7   Region                               717 non-null    object
#  8   Business Unit                        126 non-null    object
#  9   Employment Status                    817 non-null    object
#  10  Career move to public sector         822 non-null    bool
# ...

# %% [markdown]
# - A lot of the columns contain the same info in both datasets but they have different column names
# - we are going to update the names for easier manipulation

# %%
dete_survey_updated.columns = dete_survey_updated.columns.str.replace(' ', '_').str.lower().str.strip().str.replace('/', '_or_')
dete_survey_updated.columns
# Out:
# Index(['id', 'separationtype', 'cease_date', 'dete_start_date',
#        'role_start_date', 'position', 'classification', 'region',
#        'business_unit', 'employment_status', 'career_move_to_public_sector',
#        'career_move_to_private_sector', 'interpersonal_conflicts',
#        'job_dissatisfaction', 'dissatisfaction_with_the_department',
#        'physical_work_environment', 'lack_of_recognition',
#        'lack_of_job_security', 'work_location', 'employment_conditions',
#        'maternity_or_family', 'relocation', 'study_or_travel', 'ill_health',
#        'traumatic_incident', 'work_life_balance', 'workload',
#        'none_of_the_above', 'gender', 'age', 'aboriginal', 'torres_strait',
#        'south_sea', 'disability', 'nesb'],
#       dtype='object')

# %%
tafe_survey_updated = tafe_survey_updated.rename(
    columns = {'Record ID' : 'id',
    'CESSATION YEAR' : 'cease_date',
    'Reason for ceasing employment': 'separationtype',
    'Gender. What is your Gender?': 'gender',
    'CurrentAge. Current Age': 'age',
    'Employment Type. Employment Type': 'employment_status',
    'Classification. Classification': 'position',
    'LengthofServiceOverall. Overall Length of Service at Institute (in years)': 'institute_service',
    'LengthofServiceCurrent. Length of Service at current workplace (in years)': 'role_service'}
)

# %% [markdown]
# - Recall that our end goal is to answer the following question:
#
#     - Are employees who have only worked for the institutes for a short period of time resigning due to some kind of dissatisfaction? What about employees who have been at the job longer?
# - If we look at the unique values in the separationtype columns in each dataframe, we'll see that each contains a couple of different separation types. For this project, we'll only analyze survey respondents who resigned, so their separation type contains the string 'Resignation'.

# %%
print(dete_survey_updated['separationtype'].value_counts())
#there is 3 different types of resignation in this df

print(tafe_survey_updated['separationtype'].value_counts())
#there is only one type of resignation in this df
# Out:
# Age Retirement                          285
# Resignation-Other reasons               150
# Resignation-Other employer               91
# Resignation-Move overseas/interstate     70
# Voluntary Early Retirement (VER)         67
# Ill Health Retirement                    61
# Other                                    49
# Contract Expired                         34
# Termination                              15
# Name: separationtype, dtype: int64
# Resignation                 340
# Contract Expired            127
# Retrenchment/ Redundancy    104
# Retirement                   82
# Transfer                     25
# Termination                  23
# Name: separationtype, dtype: int64

# %%
dete_resignations = dete_survey_updated.copy()
pattern = r"Resignation"
dete_resignations = dete_resignations[dete_resignations['separationtype'].str.contains(pattern)]
dete_resignations['separationtype'] = dete_resignations['separationtype'].str.split('-').str[0]
dete_resignations = dete_resignations.reset_index()
dete_resignations
# Out:
#      index   id separationtype cease_date  dete_start_date  role_start_date  \
# 0        3    4    Resignation    05/2012           2005.0           2006.0
# 1        5    6    Resignation    05/2012           1994.0           1997.0
# 2        8    9    Resignation    07/2012           2009.0           2009.0
# 3        9   10    Resignation       2012           1997.0           2008.0
# 4       11   12    Resignation       2012           2009.0           2009.0
# ..     ...  ...            ...        ...              ...              ...
# 306    808  810    Resignation    12/2013           2010.0           2010.0
# 307    815  817    Resignation    01/2014           2012.0           2012.0
# 308    816  818    Resignation    01/2014           2012.0           2012.0
# 309    819  821    Resignation    01/2014           2009.0           2009.0
# 310    821  823    Resignation    12/2013              NaN              NaN
#
# ...

# %%
tafe_resignations = tafe_survey_updated.copy()
tafe_resignations = tafe_resignations[tafe_resignations['separationtype'] == 'Resignation']
tafe_resignations = tafe_resignations.reset_index()
tafe_resignations
# Out:
#      index            id                              Institute  \
# 0        3  6.341399e+17            Mount Isa Institute of TAFE
# 1        4  6.341466e+17  Southern Queensland Institute of TAFE
# 2        5  6.341475e+17  Southern Queensland Institute of TAFE
# 3        6  6.341520e+17         Barrier Reef Institute of TAFE
# 4        7  6.341537e+17  Southern Queensland Institute of TAFE
# ..     ...           ...                                    ...
# 335    696  6.350660e+17  Southern Queensland Institute of TAFE
# 336    697  6.350668e+17         Barrier Reef Institute of TAFE
# 337    698  6.350677e+17  Southern Queensland Institute of TAFE
# 338    699  6.350704e+17       Tropical North Institute of TAFE
# 339    701  6.350730e+17       Tropical North Institute of TAFE
#
#                      WorkArea  cease_date separationtype  \
# 0    Non-Delivery (corporate)      2010.0    Resignation
# 1         Delivery (teaching)      2010.0    Resignation
# ...

# %% [markdown]
# - We have sorted our datasets into two new datasets where the separation type is only to do with resignations

# %%
dete_resignations['cease_date'].value_counts()
# we have some values as just a year and some as a month and a year
#we want to have just the year so we will account for this
dete_resignations['cease_date'] = dete_resignations['cease_date'].str.split('/').str[-1]
dete_resignations['cease_date'] = dete_resignations['cease_date'].astype(float)
dete_resignations
# Out:
#      index   id separationtype  cease_date  dete_start_date  role_start_date  \
# 0        3    4    Resignation      2012.0           2005.0           2006.0
# 1        5    6    Resignation      2012.0           1994.0           1997.0
# 2        8    9    Resignation      2012.0           2009.0           2009.0
# 3        9   10    Resignation      2012.0           1997.0           2008.0
# 4       11   12    Resignation      2012.0           2009.0           2009.0
# ..     ...  ...            ...         ...              ...              ...
# 306    808  810    Resignation      2013.0           2010.0           2010.0
# 307    815  817    Resignation      2014.0           2012.0           2012.0
# 308    816  818    Resignation      2014.0           2012.0           2012.0
# 309    819  821    Resignation      2014.0           2009.0           2009.0
# 310    821  823    Resignation      2013.0              NaN              NaN
#
# ...

# %%
print(dete_resignations['cease_date'].value_counts().sort_index())

print(tafe_resignations['cease_date'].value_counts().sort_index())
# Out:
# 2006.0      1
# 2010.0      2
# 2012.0    129
# 2013.0    146
# 2014.0     22
# Name: cease_date, dtype: int64
# 2009.0      2
# 2010.0     68
# 2011.0    116
# 2012.0     94
# 2013.0     55
# Name: cease_date, dtype: int64

# %%
dete_resignations.boxplot(column=['cease_date'])
# Out:
# <AxesSubplot:>

# %%
tafe_resignations.boxplot(column=['cease_date'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# - The years in both dataframes don't completely align.
# - The tafe_survey_updated dataframe contains some cease dates in 2009, but the dete_survey_updated dataframe does not.
# - The tafe_survey_updated dataframe also contains many more cease dates in 2010 than the dete_survey_updaed dataframe.
# - Since we aren't concerned with analyzing the results by year, we'll leave them as is.

# %%
dete_resignations['institute_service'] = dete_resignations['cease_date'] - dete_resignations['dete_start_date']
dete_resignations['institute_service']
# Out:
# 0       7.0
# 1      18.0
# 2       3.0
# 3      15.0
# 4       3.0
#        ...
# 306     3.0
# 307     2.0
# 308     2.0
# 309     5.0
# 310     NaN
# Name: institute_service, Length: 311, dtype: float64

# %% [markdown]
# - In the above we calculate the length of service by subtracting the start date from the cease date
# - Something to note is some people don't have start dates AKA they are null
# - This means they are null values in our new column of data

# %% [markdown]
# - We have reasons for leaving in the dete survey as:
#     - job_dissatisfaction
#     - dissatisfaction_with_the_department
#     - physical_work_environment
#     - lack_of_recognition
#     - lack_of_job_security
#     - work_location
#     - employment_conditions
#     - work_life_balance
#     - workload
# - We have reasons for leaing in the tafe survey as:
#     - Contributing Factors. Dissatisfaction
#     - Contributing Factors. Job Dissatisfaction

# %%
dete_resignations['job_dissatisfaction'].value_counts(dropna=False)
# Out:
# False    270
# True      41
# Name: job_dissatisfaction, dtype: int64

# %%
dete_resignations['dissatisfaction_with_the_department'].value_counts(dropna=False)
# Out:
# False    282
# True      29
# Name: dissatisfaction_with_the_department, dtype: int64

# %%
dete_resignations['physical_work_environment'].value_counts(dropna=False)
# Out:
# False    305
# True       6
# Name: physical_work_environment, dtype: int64

# %%
dete_resignations['lack_of_recognition'].value_counts(dropna=False)
# Out:
# False    278
# True      33
# Name: lack_of_recognition, dtype: int64

# %%
dete_resignations['lack_of_job_security'].value_counts(dropna=False)
# Out:
# False    297
# True      14
# Name: lack_of_job_security, dtype: int64

# %%
dete_resignations['work_location'].value_counts(dropna=False)
# Out:
# False    293
# True      18
# Name: work_location, dtype: int64

# %%
dete_resignations['employment_conditions'].value_counts(dropna=False)
# Out:
# False    288
# True      23
# Name: employment_conditions, dtype: int64

# %%
dete_resignations['employment_conditions'].value_counts(dropna=False)
# Out:
# False    288
# True      23
# Name: employment_conditions, dtype: int64

# %%
dete_resignations['work_life_balance'].value_counts(dropna=False)
# Out:
# False    243
# True      68
# Name: work_life_balance, dtype: int64

# %%
dete_resignations['workload'].value_counts(dropna=False)
# Out:
# False    284
# True      27
# Name: workload, dtype: int64

# %%
def update_vals(value):
    if pd.isnull(value):
        return np.nan
    else:
        return True

dissatisfied_cols_dete = ['job_dissatisfaction',
                         'dissatisfaction_with_the_department',
                         'physical_work_environment',
                         'lack_of_recognition',
                         'lack_of_job_security',
                         'work_location',
                         'employment_conditions',
                         'employment_conditions',
                         'work_life_balance',
                         'workload']

dete_resignations['dissatisfied'] = dete_resignations[['job_dissatisfaction',
                         'dissatisfaction_with_the_department',
                         'physical_work_environment',
                         'lack_of_recognition',
                         'lack_of_job_security',
                         'work_location',
                         'employment_conditions',
                         'employment_conditions',
                         'work_life_balance',
                         'workload']].map(update_vals)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-199-feeeeb132455> in <module>
#      16                          'workload']
#      17
# ---> 18 dete_resignations['dissatisfied'] = dete_resignations[['job_dissatisfaction',
#      19                          'dissatisfaction_with_the_department',
#      20                          'physical_work_environment',
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'map'
